# %% [markdown]
# <a href="https://colab.research.google.com/github/ziadkhalil04-jpg/ML-internship_test/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ziadkhalil04-jpg/ML-internship_test/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Selected Lane: Lane 1 - Ranking Signal Analysis
# Research Question: Which safe content and search signals are associated with visibility, clicks, engagement, or movement?
# Why this lane: I chose Lane 1 because understanding how content characteristics and search signals directly influence organic visibility and user engagement is essential for driving data-backed SEO decisions and content optimization strategies.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os

if not os.path.exists("ML-internship_test"):
    # !git clone https://github.com/ziadkhalil04-jpg/ML-internship_test.git

df = pd.read_csv("ML-internship_test/data/raw/content_refresh_anonymized.csv")

print(f"Total pages in dataset: {len(df):,}")
if 'clicks' in df.columns:
    print(f"Average clicks per page: {df['clicks'].mean():.2f}")
if 'impressions' in df.columns:
    print(f"Average impressions per page: {df['impressions'].mean():.2f}")
# Out:
# Total pages in dataset: 30,000

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research Question: Which safe content and search signals are associated with visibility, clicks, engagement, or movement?
# Unit of Analysis: A single Web Page / URL.
# Decision & Action: Identify key ranking signals to prioritize specific SEO and content optimizations that yield the highest impact on visibility and traffic.
# Cost of a Wrong Call: Wasting team resources and engineering time on optimizing signals that do not actually drive traffic, potentially risking organic search visibility.
# Why Data/ML: Search algorithms involve complex, non-linear multi-variable interactions that require statistical modeling and machine learning to evaluate accurately rather than relying on intuition or static rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os

if not os.path.exists("ML-internship_test"):
    # !git clone https://github.com/ziadkhalil04-jpg/ML-internship_test.git

df = pd.read_csv("ML-internship_test/data/raw/content_refresh_anonymized.csv")

print(f"Total pages in starter dataset: {len(df):,}")
if 'clicks' in df.columns:
    print(f"Average clicks per page: {df['clicks'].mean():.2f}")
if 'impressions' in df.columns:
    print(f"Average impressions per page: {df['impressions'].mean():.2f}")
# Out:
# Total pages in starter dataset: 30,000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I CAN claim: We can observe statistical associations and correlations between specific content/search signals and organic search performance metrics within our sample data.
# What I CANNOT claim: We cannot claim absolute direct causality or guarantee that changing a specific signal will immediately alter Google's ranking algorithm, as search engine ranking factors involve external non-observable variables and algorithmic updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decxision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
